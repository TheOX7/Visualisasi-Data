# %% [markdown]
# # Import Modules
#
# ---

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# ---
#
# # Pandas 37 | Seleksi baris dengan banyak kriteria pada Data Frame
#
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
df = pd.read_csv('/content/titanic_full.csv')
df
# Out:
#       survived                                             name     sex  \
# 0            1                    Allen, Miss. Elisabeth Walton  female
# 1            1                   Allison, Master. Hudson Trevor    male
# 2            0                     Allison, Miss. Helen Loraine  female
# 3            0             Allison, Mr. Hudson Joshua Creighton    male
# 4            0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...        ...                                              ...     ...
# 1304         0                             Zabour, Miss. Hileni  female
# 1305         0                            Zabour, Miss. Thamine  female
# 1306         0                        Zakarian, Mr. Mapriededer    male
# 1307         0                              Zakarian, Mr. Ortin    male
# 1308         0                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  pclass  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ## Seleksi baris dengan banyak kriteria

# %%
df[(df['sex']=='female') & (df['age']>=60) & (df['embarked']=='S') & (df['survived']==1)]
# Out:
#       survived                                               name     sex  \
# 6            1                  Andrews, Miss. Kornelia Theodosia  female
# 61           1  Cavendish, Mrs. Tyrell William (Julia Florence...  female
# 83           1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female
# 116          1                Fortune, Mrs. Mark (Mary McDougald)  female
# 1261         1                             Turkula, Mrs. (Hedwig)  female
#
#        age  sibsp  parch  pclass  ticket      fare        cabin embarked boat  \
# 6     63.0      1      0       1   13502   77.9583           D7        S   10
# 61    76.0      1      0       1   19877   78.8500          C46        S    6
# 83    64.0      1      1       1  112901   26.5500          B26        S    7
# 116   60.0      1      4       1   19950  263.0000  C23 C25 C27        S   10
# 1261  63.0      0      0       3    4134    9.5875          NaN        S   15
#
#       body                home.dest
# ...

# %%
df[
    (df['sex']=='female') & 
    (df['age']>=60) &
    (df['embarked']=='S') &
    (df['survived']==1)
    ]
# Out:
#       survived                                               name     sex  \
# 6            1                  Andrews, Miss. Kornelia Theodosia  female
# 61           1  Cavendish, Mrs. Tyrell William (Julia Florence...  female
# 83           1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female
# 116          1                Fortune, Mrs. Mark (Mary McDougald)  female
# 1261         1                             Turkula, Mrs. (Hedwig)  female
#
#        age  sibsp  parch  pclass  ticket      fare        cabin embarked boat  \
# 6     63.0      1      0       1   13502   77.9583           D7        S   10
# 61    76.0      1      0       1   19877   78.8500          C46        S    6
# 83    64.0      1      1       1  112901   26.5500          B26        S    7
# 116   60.0      1      4       1   19950  263.0000  C23 C25 C27        S   10
# 1261  63.0      0      0       3    4134    9.5875          NaN        S   15
#
#       body                home.dest
# ...

# %%
kr1 = (df['sex']=='female')
kr2 = (df['age']>=60)
kr3 = (df['embarked']=='S')
kr4 = (df['survived']==1)

df[kr1 & kr2 & kr3 & kr4]
# Out:
#       survived                                               name     sex  \
# 6            1                  Andrews, Miss. Kornelia Theodosia  female
# 61           1  Cavendish, Mrs. Tyrell William (Julia Florence...  female
# 83           1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female
# 116          1                Fortune, Mrs. Mark (Mary McDougald)  female
# 1261         1                             Turkula, Mrs. (Hedwig)  female
#
#        age  sibsp  parch  pclass  ticket      fare        cabin embarked boat  \
# 6     63.0      1      0       1   13502   77.9583           D7        S   10
# 61    76.0      1      0       1   19877   78.8500          C46        S    6
# 83    64.0      1      1       1  112901   26.5500          B26        S    7
# 116   60.0      1      4       1   19950  263.0000  C23 C25 C27        S   10
# 1261  63.0      0      0       3    4134    9.5875          NaN        S   15
#
#       body                home.dest
# ...

# %% [markdown]
# ---
#
# # Pandas 38 | Parameter header dan skiprows pada read_csv
#
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
df = pd.read_csv('/content/Iris_error.csv')
df.head(8)
# Out:
#     1            5.1           2.2            1.3           0.3   Iris-error
# 0   2            4.9           3.0            1.4           0.2   Iris-error
# 1  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   1            5.1           3.5            1.4           0.2  Iris-setosa
# 3   2            4.9           3.0            1.4           0.2  Iris-setosa
# 4   3            4.7           3.2            1.3           0.2   Iris-error
# 5   4            4.6           3.1            1.5           0.2   Iris-error
# 6   5            5.0           3.6            1.4           0.2  Iris-setosa
# 7   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df = pd.read_csv('/content/Iris_error.csv', header=2, skiprows=[5,6])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   5            5.0           3.6            1.4           0.2  Iris-setosa
# 3   6            5.4           3.9            1.7           0.4  Iris-setosa
# 4   7            4.6           3.4            1.4           0.3  Iris-setosa

# %% [markdown]
# ---
#
# # Pandas 39 | Mengacak urutan baris pada Data Frame
#
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
n_rows = 6
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 5, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  2  3  1  2  1
# 1  4  3  1  4  2
# 2  2  2  3  4  3
# 3  4  4  4  2  3
# 4  2  2  4  3  3
# 5  3  1  1  4  3

# %% [markdown]
# ## Mengacak urutan baris pada DataFrame

# %%
df.sample(frac=1.0, random_state=1)
# Out:
#    A  B  C  D  E
# 2  2  2  3  4  3
# 1  4  3  1  4  2
# 4  2  2  4  3  3
# 0  2  3  1  2  1
# 3  4  4  4  2  3
# 5  3  1  1  4  3

# %%
df.sample(frac=1.0, random_state=1).reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  2  2  3  4  3
# 1  4  3  1  4  2
# 2  2  2  4  3  3
# 3  2  3  1  2  1
# 4  4  4  4  2  3
# 5  3  1  1  4  3

# %% [markdown]
# ---
#
# # Pandas 40 | Akses sekelompok data pada Data Frame yang sudah terkelompok
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
df = pd.read_csv('/content/titanic_full.csv')
df.head()
# Out:
#    survived                                             name     sex      age  \
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         0                     Allison, Miss. Helen Loraine  female   2.0000
# 3         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  pclass  ticket      fare    cabin embarked boat   body  \
# 0      0      0       1   24160  211.3375       B5        S    2    NaN
# 1      1      2       1  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2       1  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2       1  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2       1  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ## Mengakses sekelompok data dengan **get_group()**

# %%
grouped_df = df.groupby('sex')

# %%
grouped_df.get_group('female').head(10)
# Out:
#     survived                                               name     sex   age  \
# 0          1                      Allen, Miss. Elisabeth Walton  female  29.0
# 2          0                       Allison, Miss. Helen Loraine  female   2.0
# 4          0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 6          1                  Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12         1                      Aubart, Mme. Leontine Pauline  female  24.0
# 13         1                       Barber, Miss. Ellen "Nellie"  female  26.0
# 17         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 18         1                              Bazzani, Miss. Albina  female  32.0
#
#     sibsp  parch  pclass    ticket      fare    cabin embarked boat  body  \
# ...

# %%
grouped_df = df.groupby('survived')

# %%
grouped_df.get_group(1).head(10)
# Out:
#     survived                                               name     sex  \
# 0          1                      Allen, Miss. Elisabeth Walton  female
# 1          1                     Allison, Master. Hudson Trevor    male
# 5          1                                Anderson, Mr. Harry    male
# 6          1                  Andrews, Miss. Kornelia Theodosia  female
# 8          1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# 12         1                      Aubart, Mme. Leontine Pauline  female
# 13         1                       Barber, Miss. Ellen "Nellie"  female
# 14         1               Barkworth, Mr. Algernon Henry Wilson    male
# 17         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female
#
#         age  sibsp  parch  pclass    ticket      fare    cabin embarked boat  \
# 0   29.0000      0      0       1     24160  211.3375       B5        S    2
# ...
