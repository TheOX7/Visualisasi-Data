# %% [markdown]
# # Import Modules
#
# ---

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# ---
#
# # Pandas 33 | Nilai Kumulatif pada Pandas Data Frame
#
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
d = {
    'players' : ['Budi', 'Joni', 'Iwan', 'Budi', 'Budi', 'Iwan', 'Asep', 'Joni'],
    'goals' : [2, 1, 3, 1, 1, 2, 2, 3]
}

df = pd.DataFrame(d)
df
# Out:
#   players  goals
# 0    Budi      2
# 1    Joni      1
# 2    Iwan      3
# 3    Budi      1
# 4    Budi      1
# 5    Iwan      2
# 6    Asep      2
# 7    Joni      3

# %% [markdown]
# ## Menampilkan nilai kumulatif

# %%
df['goals'].cumsum().to_frame()
# Out:
#    goals
# 0      2
# 1      3
# 2      6
# 3      7
# 4      8
# 5     10
# 6     12
# 7     15

# %%
df['cummulative_goal_counts'] = df['goals'].cumsum().to_frame()
df
# Out:
#   players  goals  cummulative_goal_counts
# 0    Budi      2                        2
# 1    Joni      1                        3
# 2    Iwan      3                        6
# 3    Budi      1                        7
# 4    Budi      1                        8
# 5    Iwan      2                       10
# 6    Asep      2                       12
# 7    Joni      3                       15

# %%
df['cummulative_goal_counts__foreach_player'] = df.groupby('players')['goals'].cumsum()
df
# Out:
#   players  goals  cummulative_goal_counts  \
# 0    Budi      2                        2
# 1    Joni      1                        3
# 2    Iwan      3                        6
# 3    Budi      1                        7
# 4    Budi      1                        8
# 5    Iwan      2                       10
# 6    Asep      2                       12
# 7    Joni      3                       15
#
#    cummulative_goal_counts__foreach_player
# 0                                        2
# 1                                        1
# 2                                        3
# 3                                        3
# 4                                        4
# 5                                        5
# 6                                        2
# 7                                        4

# %%
df['cum_max'] = df['goals'].cummax()
df
# Out:
#   players  goals  cummulative_goal_counts  \
# 0    Budi      2                        2
# 1    Joni      1                        3
# 2    Iwan      3                        6
# 3    Budi      1                        7
# 4    Budi      1                        8
# 5    Iwan      2                       10
# 6    Asep      2                       12
# 7    Joni      3                       15
#
#    cummulative_goal_counts__foreach_player  cum_max
# 0                                        2        2
# 1                                        1        2
# 2                                        3        3
# 3                                        3        3
# 4                                        4        3
# 5                                        5        3
# 6                                        2        3
# 7                                        4        3

# %%
df['cum_min'] = df['goals'].cummin()
df
# Out:
#   players  goals  cummulative_goal_counts  \
# 0    Budi      2                        2
# 1    Joni      1                        3
# 2    Iwan      3                        6
# 3    Budi      1                        7
# 4    Budi      1                        8
# 5    Iwan      2                       10
# 6    Asep      2                       12
# 7    Joni      3                       15
#
#    cummulative_goal_counts__foreach_player  cum_max  cum_min
# 0                                        2        2        2
# 1                                        1        2        1
# 2                                        3        3        1
# 3                                        3        3        1
# 4                                        4        3        1
# 5                                        5        3        1
# 6                                        2        3        1
# 7                                        4        3        1

# %%
# cumprod() --> Misal pada baris ke cum_prod = 3 bernilai 6. Didapat dari perkalian kolom goals dari baris 1 s/d 3
df['cum_prod'] = df['goals'].cumprod()
df
# Out:
#   players  goals  cummulative_goal_counts  \
# 0    Budi      2                        2
# 1    Joni      1                        3
# 2    Iwan      3                        6
# 3    Budi      1                        7
# 4    Budi      1                        8
# 5    Iwan      2                       10
# 6    Asep      2                       12
# 7    Joni      3                       15
#
#    cummulative_goal_counts__foreach_player  cum_max  cum_min  cum_prod
# 0                                        2        2        2         2
# 1                                        1        2        1         2
# 2                                        3        3        1         6
# 3                                        3        3        1         6
# 4                                        4        3        1         6
# 5                                        5        3        1        12
# 6                                        2        3        1        24
# 7                                        4        3        1        72

# %% [markdown]
# ---
#
# # Pandas 34 | Mapping Data Frame dengan applymap
#
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
d = {
    'jenis_kelamin' : ['Pria', 'Wanita', 'lelaki', 'Lelaki', 'perempuan'],
    'usia' : [23, 21, 24, 22, 21],
    'shift' : ['pagi', 'siang', 'Malam', 'Siang', 'pagi']
}

df = pd.DataFrame(d)
df
# Out:
#   jenis_kelamin  usia  shift
# 0          Pria    23   pagi
# 1        Wanita    21  siang
# 2        lelaki    24  Malam
# 3        Lelaki    22  Siang
# 4     perempuan    21   pagi

# %% [markdown]
# ## Mapping pada Dataframe dengan **applymap()**

# %%
df = df.applymap(lambda x: x.lower() if type(x) == str else x)
df
# Out:
#   jenis_kelamin  usia  shift
# 0          pria    23   pagi
# 1        wanita    21  siang
# 2        lelaki    24  malam
# 3        lelaki    22  siang
# 4     perempuan    21   pagi

# %% [markdown]
# ## **applymap()** dengan dictionary

# %%
mapping = {
    'pria' : 'L',
    'lelaki' : 'L',
    'wanita' : 'P',
    'perempuan' : 'P',
    'pagi' : 1,
    'siang' : 2,
    'malam' : 3
}

df.applymap(mapping.get)
# Out:
#   jenis_kelamin  usia  shift
# 0             L  None      1
# 1             P  None      2
# 2             L  None      3
# 3             L  None      2
# 4             P  None      1

# %%
df[['jenis_kelamin', 'shift']] = df[['jenis_kelamin', 'shift']].applymap(mapping.get)
df
# Out:
#   jenis_kelamin  usia  shift
# 0             L    23      1
# 1             P    21      2
# 2             L    24      3
# 3             L    22      2
# 4             P    21      1

# %% [markdown]
# ---
#
# # Pandas 35 | Memadukan fungsi agregasi dengan transform
#
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
d = {
    'no_nota' : [1, 1, 1, 2, 2, 3, 4, 5],
    'kopi' : ['latte', 'cappuccino', 'espresso', 'latte', 'espresso', 'cappuccino', 'latte', 'espresso'],
    'harga' : [50, 60, 80, 150, 120, 60, 100, 40]
}

df = pd.DataFrame(d)
df
# Out:
#    no_nota        kopi  harga
# 0        1       latte     50
# 1        1  cappuccino     60
# 2        1    espresso     80
# 3        2       latte    150
# 4        2    espresso    120
# 5        3  cappuccino     60
# 6        4       latte    100
# 7        5    espresso     40

# %% [markdown]
# ## Menghitung total harga untuk tiap nomor nota

# %%
df.groupby('no_nota')['harga'].sum().to_frame()
# Out:
#          harga
# no_nota
# 1          190
# 2          270
# 3           60
# 4          100
# 5           40

# %%
df['total_harga'] = df.groupby('no_nota')['harga'].transform(sum)
df
# Out:
#    no_nota        kopi  harga  total_harga
# 0        1       latte     50          190
# 1        1  cappuccino     60          190
# 2        1    espresso     80          190
# 3        2       latte    150          270
# 4        2    espresso    120          270
# 5        3  cappuccino     60           60
# 6        4       latte    100          100
# 7        5    espresso     40           40

# %% [markdown]
# ## Menghitung total omset untuk tiap jenis kopi yang terjual

# %%
df.groupby('kopi')['harga'].sum().to_frame()
# Out:
#             harga
# kopi
# cappuccino    120
# espresso      240
# latte         300

# %%
df['total_omset'] = df.groupby('kopi')['harga'].transform(sum)
df
# Out:
#    no_nota        kopi  harga  total_harga  total_omset
# 0        1       latte     50          190          300
# 1        1  cappuccino     60          190          120
# 2        1    espresso     80          190          240
# 3        2       latte    150          270          300
# 4        2    espresso    120          270          240
# 5        3  cappuccino     60           60          120
# 6        4       latte    100          100          300
# 7        5    espresso     40           40          240

# %% [markdown]
# ---
#
# # Pandas 36 | Menyatukan kolom pada Pandas Data Frame
# ---

# %% [markdown]
# ## Persiapan Data Frame

# %%
d = {
    'nama' : ['bayu', 'indra', 'devi', 'agni'],
    'jenis_kelamin' : ['L', 'L', 'P', 'L'],
    'usia' : [23, 21, 22, 25]
}

df = pd.DataFrame(d)
df
# Out:
#     nama jenis_kelamin  usia
# 0   bayu             L    23
# 1  indra             L    21
# 2   devi             P    22
# 3   agni             L    25

# %% [markdown]
# ## Menyatukan kolom dengan **str.cat()**

# %%
df['nama'].str.cat(df['jenis_kelamin'], sep=', ').to_frame()
# Out:
#        nama
# 0   bayu, L
# 1  indra, L
# 2   devi, P
# 3   agni, L

# %%
df['nama_jk'] = df['nama'].str.cat(df['jenis_kelamin'], sep=', ')
df
# Out:
#     nama jenis_kelamin  usia   nama_jk   nama_usia
# 0   bayu             L    23   bayu, L   bayu - 23
# 1  indra             L    21  indra, L  indra - 21
# 2   devi             P    22   devi, P   devi - 22
# 3   agni             L    25   agni, L   agni - 25

# %%
df['nama'].str.cat(df['usia'].astype('str'), sep=' - ').to_frame()
# Out:
#          nama
# 0   bayu - 23
# 1  indra - 21
# 2   devi - 22
# 3   agni - 25

# %%
df['nama_usia'] = df['nama'].str.cat(df['usia'].astype('str'), sep=' - ').to_frame()
df
# Out:
#     nama jenis_kelamin  usia   nama_jk   nama_usia
# 0   bayu             L    23   bayu, L   bayu - 23
# 1  indra             L    21  indra, L  indra - 21
# 2   devi             P    22   devi, P   devi - 22
# 3   agni             L    25   agni, L   agni - 25
